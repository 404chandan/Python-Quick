# %% [markdown]
# Dictionaries and Sets in Python

# %%
a={
    "name":"chandan",
    "roll_no":5,
    "marks":[76,67,89,93]
}

a["name"]
# Out:
# 'chandan'

# %%
a["marks"]
# Out:
# [76, 67, 89, 93]

# %% [markdown]
# We use dictionaries because it is unordered,mutable,indexed and cannot contain duplicate keys

# %%
a.items()
# Out:
# dict_items([('name', 'chandan'), ('roll_no', 5), ('marks', [76, 67, 89, 93])])

# %%
a.keys()
# Out:
# dict_keys(['name', 'roll_no', 'marks'])

# %%
a.update({"name":"Achintya"})
a
# Out:
# {'name': 'Achintya', 'roll_no': 5, 'marks': [76, 67, 89, 93]}

# %%
a.get("name")
# Out:
# 'Achintya'

# %% [markdown]
# Sets are Unique in Nature

# %%
s = set()
s.add(1)
s.add(2)
s.add(2)
s
# Out:
# {1, 2}

# %%
s={1,8,2,3}

# %% [markdown]
# Sets are -
# Unordered
# Unindexed
# Immutable elements
# Sets are mutable
# Unique

# %%
len(s)
# Out:
# 4

# %%
s.remove(1)
s
# Out:
# {2, 3, 8}

# %%
s.add(1)
s
# Out:
# {1, 2, 3, 8}

# %%
s.pop() #pops randomly
s
# Out:
# {1, 2, 3}

# %%
# s.clear() clears the set

# %%
s.union({8,11})
s
# Out:
# {1, 2, 3}
