# %% [markdown]
# List and its operations

# %%
l1=["chandan",7,2.0]
l1
# Out:
# ['chandan', 7, 2.0]

# %%
l1[1]
# Out:
# 7

# %%
l1[0:1]
# Out:
# ['chandan']

# %%
l1[-1]
# Out:
# 2.0

# %%
l2=[1,5,4,9,8,13]
l2.sort()
l2
# Out:
# [1, 4, 5, 8, 9, 13]

# %%
l2.reverse()
l2
# Out:
# [13, 9, 8, 5, 4, 1]

# %%
l2.append(3)

# %%
l2
# Out:
# [13, 9, 8, 5, 4, 1, 3]

# %%
l2.insert(4,7)

# %%
l2
# Out:
# [13, 9, 8, 5, 7, 4, 1, 3]

# %%
l2.pop() #last index
# Out:
# 3

# %%
l2.pop(3) #3rd index
l2
# Out:
# [13, 9, 8, 7, 4, 1]

# %%
l2.remove(13) #to remove specific element
l2
# Out:
# [9, 8, 7, 4, 1]

# %% [markdown]
# We can do all the stuffs with tuples, the difference is that tuple is immutable data type

# %%
t1=("chandan",2.0,3,3)
# t1[1]=3 -> will throw an error
t1
# Out:
# ('chandan', 2.0, 3, 3)

# %%
t1.index(2.0)
# Out:
# 1

# %%
t1.count(3)
# Out:
# 2
