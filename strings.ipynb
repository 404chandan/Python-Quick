# %% [markdown]
# Strings and Operations on Strings

# %%
a="HarryPotter"
type(a)
# Out:
# str

# %%
a[0]
# Out:
# 'H'

# %%
a[-1]
# Out:
# 'r'

# %%
a[0:4]
# Out:
# 'Harr'

# %%
a[0:-3]
# Out:
# 'HarryPot'

# %%
a[:4]
# Out:
# 'Harr'

# %%
a[1:]
# Out:
# 'arryPotter'

# %%
len(a)
# Out:
# 11

# %%
a.endswith("ry")
# Out:
# False

# %%
a.endswith("r")
# Out:
# True

# %%
b=a.capitalize()
b
# Out:
# 'Harrypotter'

# %%
a.find("y")
# Out:
# 4

# %%
b=a.replace("Harry","harry")
b
# Out:
# 'harryPotter'
