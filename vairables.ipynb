# %%
a=40
print(a*2)
# Out:
# 80

# %%
b="Harry"
print("I love "+b+"Potter")
# Out:
# I love HarryPotter

# %%
a=43
b=31
c=a/b
print(c)
print(int(c))
# Out:
# 1.3870967741935485
# 1

# %%
a=True
b=False
print(a or b)
print(a and b)
# Out:
# True
# False

# %%
a=31
b=a/3
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a=input("Enter a Number: ")
print(a)
# Out:
# Chandan
